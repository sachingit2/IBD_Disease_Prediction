# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Without Transpose.csv',index_col=0)

# %%
df.head(5)
# Out:
#                        FP42     FP45      FP48      FP50      FP51      FP52  \
# Gene
# ENSG00000223972.5  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000
# ENSG00000227232.5  0.554976  3.05873  0.615507  0.579562  0.238045  1.893621
# ENSG00000278267.1  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000
# ENSG00000243485.5  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000
# ENSG00000237613.2  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000
#
#                    FP54      FP56      FP57      FP58  ...  CFN02     CFN03  \
# Gene                                                   ...
# ENSG00000223972.5   0.0  0.000000  0.000000  0.000000  ...    0.0  0.000000
# ENSG00000227232.5   0.0  0.554414  1.513191  0.463096  ...    0.0  0.424949
# ENSG00000278267.1   0.0  0.000000  0.000000  0.000000  ...    0.0  0.000000
# ENSG00000243485.5   0.0  0.000000  0.000000  0.000000  ...    0.0  0.000000
# ...

# %%
new_df = df.transpose()

# %%
new_df.head()
# Out:
# Gene  ENSG00000223972.5  ENSG00000227232.5  ENSG00000278267.1  \
# FP42                0.0           0.554976                0.0
# FP45                0.0           3.058730                0.0
# FP48                0.0           0.615507                0.0
# FP50                0.0           0.579562                0.0
# FP51                0.0           0.238045                0.0
#
# Gene  ENSG00000243485.5  ENSG00000237613.2  ENSG00000238009.6  \
# FP42                0.0                0.0                0.0
# FP45                0.0                0.0                0.0
# FP48                0.0                0.0                0.0
# FP50                0.0                0.0                0.0
# FP51                0.0                0.0                0.0
#
# Gene  ENSG00000233750.3  ENSG00000268903.1  ENSG00000269981.1  \
# FP42           0.000000           0.513774           0.409753
# FP45           0.063999           0.000000           0.000000
# ...

# %%
from sklearn.utils import shuffle

# %%
final_df= shuffle(new_df)

# %%
final_df.head(60)
# Out:
# Gene   ENSG00000223972.5  ENSG00000227232.5  ENSG00000278267.1  \
# FN51            0.000000           0.431733                0.0
# FP82            0.000000           0.405766                0.0
# FN68            0.000000           0.806282                0.0
# FP56            0.000000           0.554414                0.0
# FN54            0.000000           1.046038                0.0
# CFN02           0.000000           0.000000                0.0
# CFN03           0.000000           0.424949                0.0
# FP57            0.000000           1.513191                0.0
# FP45            0.000000           3.058730                0.0
# UC92            0.000000           0.011076                0.0
# FP50            0.000000           0.579562                0.0
# FN48            0.000000           0.122902                0.0
# FP58            0.000000           0.463096                0.0
# FN56            0.000000           0.584521                0.0
# ...

# %%
final_df.to_csv('Final csv ML.csv')

# %%
print(final_df)
# Out:
# Gene   ENSG00000223972.5  ENSG00000227232.5  ENSG00000278267.1  \
# FN51            0.000000           0.431733                0.0
# FP82            0.000000           0.405766                0.0
# FN68            0.000000           0.806282                0.0
# FP56            0.000000           0.554414                0.0
# FN54            0.000000           1.046038                0.0
# CFN02           0.000000           0.000000                0.0
# CFN03           0.000000           0.424949                0.0
# FP57            0.000000           1.513191                0.0
# FP45            0.000000           3.058730                0.0
# UC92            0.000000           0.011076                0.0
# FP50            0.000000           0.579562                0.0
# FN48            0.000000           0.122902                0.0
# FP58            0.000000           0.463096                0.0
# FN56            0.000000           0.584521                0.0
# ...
